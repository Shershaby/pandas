# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv(r'F:\AI Diploma\New Era\S1\allyears.csv')
print(df.head())
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
df.loc[0:10,['name','sex']]
# Out:
#          name sex
# 0        Mary   F
# 1        Anna   F
# 2        Emma   F
# 3   Elizabeth   F
# 4      Minnie   F
# 5    Margaret   F
# 6         Ida   F
# 7       Alice   F
# 8      Bertha   F
# 9       Sarah   F
# 10      Annie   F

# %%
df.iloc[0:10]
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880
# 5   Margaret   F    1578  1880
# 6        Ida   F    1472  1880
# 7      Alice   F    1414  1880
# 8     Bertha   F    1320  1880
# 9      Sarah   F    1288  1880

# %%
males = df[df.sex == 'M']
males_ = males.head()
males_
# Out:
#         name sex  number  year
# 942     John   M    9655  1880
# 943  William   M    9532  1880
# 944    James   M    5927  1880
# 945  Charles   M    5348  1880
# 946   George   M    5126  1880

# %%
year = df[df.name == 'Mary']
year_ = year.head()
year_
# Out:
#       name sex  number  year
# 0     Mary   F    7065  1880
# 1273  Mary   M      27  1880
# 2000  Mary   F    6919  1881
# 3238  Mary   M      29  1881
# 3935  Mary   F    8148  1882

# %%
females = df[df.sex == 'F']
females_ = females.head()
females_
females_.plot(kind = 'hist',edgecolor='black')
plt.show()

# %%
df.median()
# Out:
# number      12.0
# year      1985.0
# Total     2006.0
# dtype: float64

# %%
df.max()
# Out:
# name      Zzyzx
# sex           M
# number    99689
# year       2018
# dtype: object

# %%
df.min()
# Out:
# name      Aaban
# sex           F
# number        5
# year       1880
# dtype: object

# %%
df.std()
# Out:
# number    1522.803579
# year        34.191213
# dtype: float64

# %%
df[['year','name']].head()
# Out:
#    year       name
# 0  1880       Mary
# 1  1880       Anna
# 2  1880       Emma
# 3  1880  Elizabeth
# 4  1880     Minnie

# %%
df.set_index(['sex', 'year']).sort_index()
# Out:
#                name  number
# sex year
# F   1880       Mary    7065
#     1880       Anna    2604
#     1880       Emma    2003
#     1880  Elizabeth    1939
#     1880     Minnie    1746
# ...             ...     ...
# M   2018      Zylas       5
#     2018      Zyran       5
#     2018      Zyrie       5
#     2018      Zyron       5
#     2018      Zzyzx       5
#
# [1957046 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['name', 'sex', 'number', 'year'], dtype='object')

# %%
df[['name','number','sex']]
# Out:
#               name  number sex
# 0             Mary    7065   F
# 1             Anna    2604   F
# 2             Emma    2003   F
# 3        Elizabeth    1939   F
# 4           Minnie    1746   F
# ...            ...     ...  ..
# 1957041      Zylas       5   M
# 1957042      Zyran       5   M
# 1957043      Zyrie       5   M
# 1957044      Zyron       5   M
# 1957045      Zzyzx       5   M
#
# [1957046 rows x 3 columns]

# %%
df[df.name == 'Mary']
# Out:
#          name sex  number  year
# 0        Mary   F    7065  1880
# 1273     Mary   M      27  1880
# 2000     Mary   F    6919  1881
# 3238     Mary   M      29  1881
# 3935     Mary   F    8148  1882
# ...       ...  ..     ...   ...
# 1825554  Mary   M       5  2014
# 1826414  Mary   F    2631  2015
# 1859539  Mary   F    2508  2016
# 1892548  Mary   F    2402  2017
# 1925138  Mary   F    2327  2018
#
# [270 rows x 4 columns]

# %%
df.describe()
# Out:
#              number          year
# count  1.957046e+06  1.957046e+06
# mean   1.796856e+02  1.975563e+03
# std    1.522804e+03  3.419121e+01
# min    5.000000e+00  1.880000e+03
# 25%    7.000000e+00  1.952000e+03
# 50%    1.200000e+01  1.985000e+03
# 75%    3.200000e+01  2.004000e+03
# max    9.968900e+04  2.018000e+03

# %%
df['Total'] = df.iloc[:, 2:4].sum(axis=1)
df.head()
# Out:
#         name sex  number  year  Total
# 0       Mary   F    7065  1880   8945
# 1       Anna   F    2604  1880   4484
# 2       Emma   F    2003  1880   3883
# 3  Elizabeth   F    1939  1880   3819
# 4     Minnie   F    1746  1880   3626

# %%
df[(df.sex == 'F') & (df.year == 1880)].head(50)
# Out:
#          name sex  number  year  Total
# 0        Mary   F    7065  1880   8945
# 1        Anna   F    2604  1880   4484
# 2        Emma   F    2003  1880   3883
# 3   Elizabeth   F    1939  1880   3819
# 4      Minnie   F    1746  1880   3626
# 5    Margaret   F    1578  1880   3458
# 6         Ida   F    1472  1880   3352
# 7       Alice   F    1414  1880   3294
# 8      Bertha   F    1320  1880   3200
# 9       Sarah   F    1288  1880   3168
# 10      Annie   F    1258  1880   3138
# 11      Clara   F    1226  1880   3106
# 12       Ella   F    1156  1880   3036
# 13   Florence   F    1063  1880   2943
# 14       Cora   F    1045  1880   2925
# 15     Martha   F    1040  1880   2920
# 16      Laura   F    1012  1880   2892
# 17     Nellie   F     995  1880   2875
# 18      Grace   F     982  1880   2862
# 19     Carrie   F     949  1880   2829
# 20      Maude   F     859  1880   2739
# 21      Mabel   F     808  1880   2688
# 22     Bessie   F     796  1880   2676
# 23     Jennie   F     793  1880   2673
# 24   Gertrude   F     787  1880   2667
# 25      Julia   F     783  1880   2663
# 26     Hattie   F     769  1880   2649
# 27      Edith   F     768  1880   2648
# 28     Mattie   F     704  1880   2584
# 29       Rose   F     700  1880   2580
# 30  Catherine   F     688  1880   2568
# 31    Lillian   F     672  1880   2552
# 32        Ada   F     652  1880   2532
# 33     Lillie   F     647  1880   2527
# 34      Helen   F     636  1880   2516
# 35     Jessie   F     635  1880   2515
# 36     Louise   F     635  1880   2515
# 37      Ethel   F     633  1880   2513
# 38       Lula   F     621  1880   2501
# 39     Myrtle   F     615  1880   2495
# 40        Eva   F     614  1880   2494
# 41    Frances   F     605  1880   2485
# 42       Lena   F     603  1880   2483
# 43       Lucy   F     590  1880   2470
# 44       Edna   F     588  1880   2468
# 45     Maggie   F     582  1880   2462
# 46      Pearl   F     569  1880   2449
# 47      Daisy   F     564  1880   2444
# 48     Fannie   F     560  1880   2440
# 49  Josephine   F     544  1880   2424
